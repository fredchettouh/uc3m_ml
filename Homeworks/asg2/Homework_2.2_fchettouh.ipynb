# %% [markdown]
# # Homework II (Part 2 out 2): Batch Normalization
#
#
#
# ------------------------------------------------------
# **Machine Learning. Master in Big Data Analytics**
#
# *Pablo M. Olmos pamartin@ing.uc3m.es*
#
# ------------------------------------------------------
#
#
# Batch normalization was introduced in Sergey Ioffe's and Christian Szegedy's 2015 paper [Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift](https://arxiv.org/pdf/1502.03167.pdf). The idea is that, instead of just normalizing the inputs to the network, we normalize the inputs to _layers within_ the network.
#
# > It's called **batch** normalization because during training, we normalize each layer's inputs by using the mean and variance of the values in the current *batch*.
#
# We will first analyze the effect of Batch Normalization (BN) in a simple NN with dense layers. Then you will be able to incorportate BN into the CNN that you designed in the first part of Lab 3.
#
# Note: a big part of the following material is a personal wrap-up of [Facebook's Deep Learning Course in Udacity](https://www.udacity.com/course/deep-learning-pytorch--ud188). So all credit goes for them!!

# %% [markdown]
# ## Batch Normalization in PyTorch<a id="implementation_1"></a>
#
# This section of the notebook shows you one way to add batch normalization to a neural network built in PyTorch.
#
# The following cells import the packages we need in the notebook and load the MNIST dataset to use in our experiments.

# %% [markdown]
# ## Batch normalization in dense and convolution layers
#
# Batch normalization addresses the issue of changing input distribution deep in the network. For example, if I trained linear model at each iteration the distribution of the inputs would be stable. In a deep neural network the distribution at iteration 10 for a deep layer can very different from the distribution at iteration 1. This because the outputs of the previous layers change every time the weights are updated. Since changes in the output propagate trough the layers this issue becomes larger the deeper we are in the network. Since are updated after every mini batch the distribution changes betweent the minibatches which is why normalization occurs at the batch layer.
# The output of each normalization is not merely the standardized value of the input but a the input scaled by a constant weight and a bias term which are learned over time.
#
# In a dense layer the mean and variance are computed with respect to all inputs at each neuron. For the convolutional layer we need to create a mean for each channel.

# %%
# %matplotlib inline

import numpy as np
import copy
import time

import torch
from torch import nn
from torch import optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# %%
### Run this cell


# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# Download and load the training  data
trainset = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
# Processing...
# Done!

# %% [markdown]
# ### Neural network classes
#
# The following class, `MLP`, allows us to create identical neural networks **with and without batch normalization** to compare. We are defining a simple NN with **two dense layers** for classification; this design choice was made to support the discussion related to batch normalization and not to get the best classification accuracy.
#
# Two importants points about BN:
#
# - We use PyTorch's [BatchNorm1d](https://pytorch.org/docs/stable/nn.html#batchnorm1d). This is the function you use to operate on linear layer outputs; you'll use [BatchNorm2d](https://pytorch.org/docs/stable/nn.html#batchnorm2d) for 2D outputs like filtered images from convolutional layers.
# - We add the batch normalization layer **before** calling the activation function.

# %%
class MLP(nn.Module):
    def __init__(self,dimx,hidden1,hidden2,nlabels,use_batch_norm=False): #Nlabels will be 10 in our case
        
        super().__init__()
        
        # Keep track of whether or not this network uses batch normalization.
        self.use_batch_norm = use_batch_norm
        
        self.output1 = nn.Linear(dimx,hidden1)
        
        self.output2 = nn.Linear(hidden1,hidden2)        
        
        self.output3 = nn.Linear(hidden2,nlabels)
    
        self.relu = nn.ReLU()
        
        self.logsoftmax = nn.LogSoftmax(dim=1)
        
        if self.use_batch_norm:

            self.batch_norm1 = nn.BatchNorm1d(hidden1)
            
            self.batch_norm2 = nn.BatchNorm1d(hidden2)
            
        
    def forward(self, x):
        x = x.view(x.shape[0],-1)
        # Pass the input tensor through each of our operations
        x = self.output1(x)
        if self.use_batch_norm:
            x = self.batch_norm1(x)
        x = self.relu(x)
        x = self.output2(x)
        if self.use_batch_norm:
            x = self.batch_norm2(x)        
        x = self.relu(x)
        x = self.output3(x)
        x = self.logsoftmax(x) 
        
        return x

# %% [markdown]
# > **Exercise:**
# >
# > - Create a validation set with the 20% of training set
# > - Extend the class above to incorporate a training method where both training and validation losses are computed, and a method to evaluate the classification performance on a given set
#
# **Note:** As we do with Dropout, for BN we have to call the methods `self.eval()` and `self.train()` in both validation and training. Setting a model to evaluation mode is important for models with batch normalization layers!
#
# >* Training mode means that the batch normalization layers will use **batch** statistics to calculate the batch norm.
# * Evaluation mode, on the other hand, uses the estimated **population** mean and variance from the entire training set, which should give us increased performance on this test data!

# %%
train_len=int(len(trainset)*0.8)

valiloader=copy.deepcopy(trainloader)

trainloader.dataset.data=trainloader.dataset.data[:train_len]
trainloader.dataset.targets=trainloader.dataset.targets[:train_len]

valiloader.dataset.data=valiloader.dataset.data[train_len:]
valiloader.dataset.targets=valiloader.dataset.targets[train_len:]

# %%
# Your code here

# %%
class MLP_extended(MLP):

    def __init__(self,dimx,hidden1,hidden2,nlabels,use_batch_norm=True, epochs=10, lr=0.001):
      super().__init__(dimx,hidden1,hidden2,nlabels,use_batch_norm=False)
      self.epochs = epochs 
      self.optimizer=optim.Adam(self.parameters(), lr=lr)
      self.criterion=torch.nn.NLLLoss()


      self.vali_loss=[]
      self.accuracy=[]
      self.train_loss=[]
      self.test_accuracy=0
      # self.cuda()

    def validate(self, valiloader):
      self.eval()
      val_accuracy = 0
      val_loss = 0

      with torch.no_grad():
        for images, targets in valiloader:
          # images, targets = images.cuda(), targets.cuda()

          log_proba=self.forward(images)
         
          loss=self.criterion(log_proba,targets)

          val_loss+=loss.item()

          proba=torch.exp(log_proba)

          top_p, top_c = proba.topk(1, dim=1)
          equals = top_c ==targets.view(*top_c.shape)
          val_accuracy +=torch.mean(equals.type(torch.FloatTensor))
        
        else:
          self.vali_loss.append(val_loss/len(valiloader))
          self.accuracy.append(val_accuracy/len(valiloader)) 

          print("Validation loss: {}" .format(self.vali_loss[-1]))
          print("Validation Accuracy : {}\n\n" .format(self.accuracy[-1]))

          self.train()

    def train_loop(self, trainloader, valiloader=None):
      for e in range(self.epochs):
        start_time=time.time()
        running_loss=0

        for images, targets in trainloader:
        
          # images,targets=images.cuda(), targets.cuda()
          self.optimizer.zero_grad()

          log_proba=self(images)
          loss=self.criterion(log_proba,targets)
          loss.backward()

          self.optimizer.step()
        
          running_loss+=loss.item()

        else:
          end_time=time.time()
          self.train_loss.append(running_loss/len(trainloader))
          print(20*'_'+'Running Epoch {}'.format(e+1)+180*'_'+'\n')
          print("Training loss: {}".format(self.train_loss[-1]))
          print("This epoch took {} seconds to train\n".format(round(end_time-start_time)))
          if valiloader:
            self.validate(valiloader)

    def testing(self, testloader):
      self.eval()
      for images, targets in testloader:
        # images,targets=images.cuda(), targets.cuda()
      
        log_proba=self(images)
        proba=torch.exp(log_proba)

        top_p, top_c= proba.topk(1, dim=1)
        equals=top_c==targets.view(*top_c.shape)


        self.test_accuracy+=torch.mean(equals.type(torch.FloatTensor))


      else:
        print('Accuracy on the test set is: {}'.format(self.test_accuracy/len(testloader)))
      return

# %% [markdown]
# ### Create two different models for testing
#
# * `net_batchnorm` uses batch normalization applied to the output of its hidden layers
# * `net_no_norm` does not use batch normalization
#
# Besides the normalization layers, everthing about these models is the same.

# %%
net_batchnorm = MLP_extended(dimx=784,hidden1=128,hidden2=64,
                              nlabels=10,epochs=10,lr=1e-3,use_batch_norm=True)
net_no_norm = MLP_extended(dimx=784,hidden1=128,hidden2=64,
                              nlabels=10,epochs=10,lr=1e-3,use_batch_norm=False)

print(net_batchnorm)
print()
print(net_no_norm)
# Out:
# MLP_extended(
#   (output1): Linear(in_features=784, out_features=128, bias=True)
#   (output2): Linear(in_features=128, out_features=64, bias=True)
#   (output3): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
#   (logsoftmax): LogSoftmax()
#   (criterion): NLLLoss()
# )
#
# MLP_extended(
#   (output1): Linear(in_features=784, out_features=128, bias=True)
#   (output2): Linear(in_features=128, out_features=64, bias=True)
#   (output3): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
#   (logsoftmax): LogSoftmax()
#   (criterion): NLLLoss()
# )

# %% [markdown]
# > **Exercise:** Train both models and compare the evolution of the train/validation loss in both cases

# %%
net_batchnorm.train_loop(trainloader,valiloader)
net_batchnorm.testing(testloader)
# Out:
# ____________________Running Epoch 1____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.6541432928505951
# This epoch took 3 seconds to train
#
# Validation loss: 0.3562145022855651
# Validation Accuracy : 0.8933971524238586
#
#
# ____________________Running Epoch 2____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.3309376639866732
# This epoch took 2 seconds to train
#
# Validation loss: 0.2936151852050135
# Validation Accuracy : 0.9108222723007202
#
#
# ____________________Running Epoch 3____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2566576819049149
# This epoch took 3 seconds to train
#
# Validation loss: 0.2527057562143572
# Validation Accuracy : 0.9197148084640503
#
#
# ____________________Running Epoch 4____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2123947934951724
# This epoch took 3 seconds to train
#
# Validation loss: 0.24742503536324348
# Validation Accuracy : 0.9230991005897522
#
#
# ____________________Running Epoch 5____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1730432402251697
# This epoch took 3 seconds to train
#
# Validation loss: 0.19673209787616808
# Validation Accuracy : 0.9396241307258606
#
#
# ____________________Running Epoch 6____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.15136611361692592
# This epoch took 3 seconds to train
#
# Validation loss: 0.227104262118378
# Validation Accuracy : 0.9290394186973572
#
#
# ____________________Running Epoch 7____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1301373218118054
# This epoch took 2 seconds to train
#
# Validation loss: 0.1691921921747346
# Validation Accuracy : 0.9494527578353882
#
#
# ____________________Running Epoch 8____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11389934003913427
# This epoch took 2 seconds to train
#
# Validation loss: 0.16553084095639567
# Validation Accuracy : 0.9487687349319458
#
#
# ____________________Running Epoch 9____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.09528088922483649
# This epoch took 2 seconds to train
#
# Validation loss: 0.16891063755798724
# Validation Accuracy : 0.9487687349319458
#
#
# ____________________Running Epoch 10____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.08611272480641681
# This epoch took 3 seconds to train
#
# Validation loss: 0.16718707912631572
# Validation Accuracy : 0.9520449638366699
#
#
# Accuracy on the test set is: 0.9505374431610107

# %%
net_no_norm.train_loop(trainloader,valiloader)
net_no_norm.testing(testloader)
# Out:
# ____________________Running Epoch 1____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.6650253648801547
# This epoch took 2 seconds to train
#
# Validation loss: 0.3986229105822502
# Validation Accuracy : 0.8783122301101685
#
#
# ____________________Running Epoch 2____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.33500413893441844
# This epoch took 2 seconds to train
#
# Validation loss: 0.31427947527939276
# Validation Accuracy : 0.9062860012054443
#
#
# ____________________Running Epoch 3____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.27286241878944684
# This epoch took 2 seconds to train
#
# Validation loss: 0.2637525175607974
# Validation Accuracy : 0.9165107011795044
#
#
# ____________________Running Epoch 4____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2198142522143397
# This epoch took 2 seconds to train
#
# Validation loss: 0.23107564208968992
# Validation Accuracy : 0.9292914271354675
#
#
# ____________________Running Epoch 5____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.17982258228206538
# This epoch took 3 seconds to train
#
# Validation loss: 0.2084252458185919
# Validation Accuracy : 0.9360238909721375
#
#
# ____________________Running Epoch 6____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.15141792946714697
# This epoch took 3 seconds to train
#
# Validation loss: 0.18440363622240483
# Validation Accuracy : 0.9440523982048035
#
#
# ____________________Running Epoch 7____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.13355981050876947
# This epoch took 3 seconds to train
#
# Validation loss: 0.19498615729953012
# Validation Accuracy : 0.9394801259040833
#
#
# ____________________Running Epoch 8____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.10914880636988616
# This epoch took 3 seconds to train
#
# Validation loss: 0.17044236568073112
# Validation Accuracy : 0.9490207433700562
#
#
# ____________________Running Epoch 9____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.09775598471363385
# This epoch took 2 seconds to train
#
# Validation loss: 0.1697724819664032
# Validation Accuracy : 0.9500288367271423
#
#
# ____________________Running Epoch 10____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.08808701349861496
# This epoch took 3 seconds to train
#
# Validation loss: 0.18567936591083004
# Validation Accuracy : 0.9429003000259399
#
#
# Accuracy on the test set is: 0.9483479261398315

# %% [markdown]
# ---
# ### Considerations for other network types
#
# This notebook demonstrates batch normalization in a standard neural network with fully connected layers. You can also use batch normalization in other types of networks, but there are some special considerations.
#
# #### ConvNets
#
# Convolution layers consist of multiple feature maps. (Remember, the depth of a convolutional layer refers to its number of feature maps.) And the weights for each feature map are shared across all the inputs that feed into the layer. Because of these differences, batch normalizing convolutional layers requires batch/population mean and variance per feature map rather than per node in the layer.
#
# > To apply batch normalization on the outputs of convolutional layers, we use [BatchNorm2d](https://pytorch.org/docs/stable/nn.html#batchnorm2d). To use it, we simply state the **number of input feature maps**. I.e. `nn.BatchNorm2d(num_features=nmaps)`
#
#
# #### RNNs
#
# Batch normalization can work with recurrent neural networks, too, as shown in the 2016 paper [Recurrent Batch Normalization](https://arxiv.org/abs/1603.09025). It's a bit more work to implement, but basically involves calculating the means and variances per time step instead of per layer. You can find an example where someone implemented recurrent batch normalization in PyTorch, in [this GitHub repo](https://github.com/jihunchoi/recurrent-batch-normalization-pytorch).

# %% [markdown]
# For 10 epochs, the model with batch normialization, is slightly 0.0017 better. Whether or not this is cooincidence or not is not clear from this approach.

# %% [markdown]
# > **Exercise:** Incorporate BN to your solution of Homework 2 (Part I). Compare the results with and without BN!!

# %%
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=256, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=256, shuffle=True)




# creating the valiation dataset


train_len=int(len(trainset)*0.8)

valiloader=copy.deepcopy(trainloader)

trainloader.dataset.data=trainloader.dataset.data[:train_len]
trainloader.dataset.targets=trainloader.dataset.targets[:train_len]

valiloader.dataset.data=valiloader.dataset.data[train_len:]
valiloader.dataset.targets=valiloader.dataset.targets[train_len:]
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting /root/.pytorch/F_MNIST_data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/F_MNIST_data/FashionMNIST/raw
# Processing...
# Done!

# %%
train_on_gpu = torch.cuda.is_available()
if(train_on_gpu):
    print('Training on GPU!')
else: 
    print('No GPU available, training on CPU; consider making n_epochs very small.')
# Out:
# Training on GPU!

# %%
class Lenet5(nn.Module):
  def __init__(self, dimx, nlabels, drop_proba=0.2,use_drop_out=False,use_batch_norm=False):
    super().__init__()

    self.conv1=nn.Conv2d(1,6,kernel_size=5, stride=1, padding=0)

    self.conv2=nn.Conv2d(6,16,kernel_size=5,stride=1, padding=0)

    self.pool=nn.MaxPool2d(2,2)

    self.final_dim=int(((dimx-4)/2-4)/2)


    self.fc1=nn.Linear(256, 120)
    self.fc2=nn.Linear(120, 84)
    self.fc3=nn.Linear(84,10)
    self.relu=nn.ReLU()
    self.use_drop=use_drop_out
    self.use_batch_norm=use_batch_norm
    if self.use_drop:
      print('Using Dropout')
      self.dropout=nn.Dropout(p=drop_proba)
    else:
      print('Not using Dropout')
    self.softmax=nn.LogSoftmax(dim=1)

    if self.use_batch_norm:
      print('Using Batch Nornmalization')
      self.batch_norm1 = nn.BatchNorm2d(num_features=6,affine=True)
      self.batch_norm2 = nn.BatchNorm2d(num_features=16,affine=True)

    else:
      print('Not using Batch Normalization')




  def forward(self,x):
    x=self.conv1(x)
    if self.use_batch_norm:
      x=self.batch_norm1(x)
      # according to: https://machinelearningmastery.com/batch-normalization-for-training-of-deep-neural-networks/
      # we should use batchnormalization before the activation for non linear activation functions.
    x=self.relu(x)
    # th size is gonna change to dimx-kernel_size/1+1
    # pooling squashes both height and width by factor 2
    x=self.pool(x)
    x=self.conv2(x)
    if self.use_batch_norm:
      x=self.batch_norm2(x)
    x=self.relu(x)
    x=self.pool(x)
    # stackup the 3 dimensional tensor
    # 16 channels, and a height/widt of final_dim
    # -1 accounts for the batch size
    
    x=x.view(-1,16*self.final_dim**2)
    x=self.relu(self.fc1(x))
    if self.use_drop:
      x=self.dropout(x)
    x=self.relu(self.fc2(x))
    if self.use_drop:
      x=self.dropout(x)
    output=self.softmax(self.fc3(x))

    return output

# %%
class Lenet5_ext(Lenet5):
  def __init__(self, dimx, nlabels, lr=0.001, epochs=2,use_cuda=True,drop_proba=0.2,use_drop_out=False, use_batch_norm=False):
    super().__init__(dimx, nlabels,drop_proba,use_drop_out,use_batch_norm)

    self.epochs=epochs

    self.optimizer=optim.Adam(self.parameters(), lr=lr)
    self.criterion=nn.NLLLoss()

    self.vali_loss=[]
    self.accuracy=[]
    self.train_loss=[]
    self.use_cuda=use_cuda
    self.test_accuracy=0


    if train_on_gpu and self.use_cuda:
        print('Using GPU')
        self.cuda()
    else:
        print('Using CPU')
        self.cpu()

  def validate(self,valiloader):
      self.eval()
      val_accuracy=0
      val_loss=0

      with torch.no_grad():
        for images, targets in valiloader:
          if train_on_gpu and self.use_cuda:
            images,targets=images.cuda(),targets.cuda()

          log_proba=self.forward(images)
          loss=self.criterion(log_proba,targets)

          val_loss+=loss.item()

          proba=torch.exp(log_proba)

          top_p, top_c = proba.topk(1, dim=1)
          equals = top_c ==targets.view(*top_c.shape)
          val_accuracy +=torch.mean(equals.type(torch.FloatTensor))


        else:
          self.vali_loss.append(val_loss/len(valiloader))
          self.accuracy.append(val_accuracy/len(valiloader)) 

          print("Validation loss: {}" .format(self.vali_loss[-1]))
          print("Validation Accuracy : {}\n\n" .format(self.accuracy[-1]))

          self.train()

  def train_loop(self,trainloader,valiloader=None,use_cuda=True, early_stopping=False):
    increasing_valiLoss=0
      
    self.train()

    for e in range(self.epochs):
      

      # print(self.fc1.weight)
      start_time=time.time()

      running_loss=0

      for images, targets in trainloader:
        if train_on_gpu and self.use_cuda:
          images,targets=images.cuda(), targets.cuda()
        self.optimizer.zero_grad()
        
        log_proba=self(images)
        loss=self.criterion(log_proba,targets)
        loss.backward()
        # for param in self.parameters():
        #   print(param.grad.data.sum())

        # # start debugger
        # import pdb; pdb.set_trace()

        self.optimizer.step()

        running_loss+=loss.item()

        
      else:
        end_time=time.time()
        self.train_loss.append(running_loss/len(trainloader))
        print(20*'_'+'Running Epoch {}'.format(e+1)+180*'_'+'\n')
        print("Training loss: {}".format(self.train_loss[-1]))
        print("This epoch took {} seconds to train\n".format(round(end_time-start_time)))
        if valiloader:
            self.validate(valiloader)

            try:
              if early_stopping and self.validation_loss[-1]>self.validation_loss[-2] :
                increasing_valiLoss+=1
              else:
                increasing_valiLoss=0
            except:
              IndexError
            if  increasing_valiLoss>=2:
              return

  def testing(self, testloader):
    for images, targets in testloader:
      if train_on_gpu and self.use_cuda:
        images,targets=images.cuda(), targets.cuda()
      
      log_proba=self.forward(images)
      proba=torch.exp(log_proba)

      top_p, top_c= proba.topk(1, dim=1)
      equals=top_c==targets.view(*top_c.shape)


      self.test_accuracy+=torch.mean(equals.type(torch.FloatTensor))


    else:
      print('Accuracy on the test set is: {}'.format(self.test_accuracy/len(testloader)))
      return

# %% [markdown]
# We will compare the model from homework without dropout or early stopping against the the model with batch_normalization.

# %%
model_overfitting=Lenet5_ext(28, 10, lr=0.001, epochs=50,use_cuda=True,use_drop_out=False,use_batch_norm=True)
model_overfitting.train_loop(trainloader, valiloader)
model_overfitting.testing(testloader)
# Out:
# Not using Dropout
# Using Batch Nornmalization
# Using GPU
# ____________________Running Epoch 1____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.6812205279761172
# This epoch took 7 seconds to train
#
# Validation loss: 0.43248051214725414
# Validation Accuracy : 0.8411023020744324
#
#
# ____________________Running Epoch 2____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.39090870915258186
# This epoch took 7 seconds to train
#
# Validation loss: 0.36498835619459763
# Validation Accuracy : 0.8679711222648621
#
#
# ____________________Running Epoch 3____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.34224427174380484
# This epoch took 7 seconds to train
#
# Validation loss: 0.33987502848848383
# Validation Accuracy : 0.8795236349105835
#
#
# ____________________Running Epoch 4____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.31477205368115546
# This epoch took 7 seconds to train
#
# Validation loss: 0.33009197832422055
# Validation Accuracy : 0.8841184973716736
#
#
# ____________________Running Epoch 5____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.290439238177335
# This epoch took 7 seconds to train
#
# Validation loss: 0.32074810120653596
# Validation Accuracy : 0.8844034671783447
#
#
# ____________________Running Epoch 6____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.27914346675289436
# This epoch took 7 seconds to train
#
# Validation loss: 0.30286517992932743
# Validation Accuracy : 0.890434980392456
#
#
# ____________________Running Epoch 7____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.26715051913832094
# This epoch took 7 seconds to train
#
# Validation loss: 0.30004033382902756
# Validation Accuracy : 0.8939613103866577
#
#
# ____________________Running Epoch 8____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2586102677469558
# This epoch took 7 seconds to train
#
# Validation loss: 0.30251652160857584
# Validation Accuracy : 0.8904706239700317
#
#
# ____________________Running Epoch 9____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2498053974135125
# This epoch took 7 seconds to train
#
# Validation loss: 0.30429696466060396
# Validation Accuracy : 0.8908624649047852
#
#
# ____________________Running Epoch 10____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2407591332622031
# This epoch took 7 seconds to train
#
# Validation loss: 0.28737303582911794
# Validation Accuracy : 0.8987461924552917
#
#
# ____________________Running Epoch 11____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.23641631776031027
# This epoch took 7 seconds to train
#
# Validation loss: 0.2834673777539679
# Validation Accuracy : 0.8975707292556763
#
#
# ____________________Running Epoch 12____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.22369384099828435
# This epoch took 7 seconds to train
#
# Validation loss: 0.2924551247282231
# Validation Accuracy : 0.8928927779197693
#
#
# ____________________Running Epoch 13____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.21690336258170453
# This epoch took 7 seconds to train
#
# Validation loss: 0.2918351891827076
# Validation Accuracy : 0.8947805762290955
#
#
# ____________________Running Epoch 14____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.21025739213887681
# This epoch took 7 seconds to train
#
# Validation loss: 0.2953729439289012
# Validation Accuracy : 0.8971789479255676
#
#
# ____________________Running Epoch 15____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.20621206694619454
# This epoch took 7 seconds to train
#
# Validation loss: 0.2887497566481854
# Validation Accuracy : 0.8988174200057983
#
#
# ____________________Running Epoch 16____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.19992607831954956
# This epoch took 7 seconds to train
#
# Validation loss: 0.292138638965627
# Validation Accuracy : 0.8988174200057983
#
#
# ____________________Running Epoch 17____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.19032401658911655
# This epoch took 7 seconds to train
#
# Validation loss: 0.2858758892150635
# Validation Accuracy : 0.8995535969734192
#
#
# ____________________Running Epoch 18____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.18682145097471298
# This epoch took 7 seconds to train
#
# Validation loss: 0.28274824644656893
# Validation Accuracy : 0.9039703607559204
#
#
# ____________________Running Epoch 19____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1808706916313856
# This epoch took 7 seconds to train
#
# Validation loss: 0.2921080731965126
# Validation Accuracy : 0.896324098110199
#
#
# ____________________Running Epoch 20____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1744084343155648
# This epoch took 7 seconds to train
#
# Validation loss: 0.2973566987413041
# Validation Accuracy : 0.8985205888748169
#
#
# ____________________Running Epoch 21____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.17239806567259292
# This epoch took 7 seconds to train
#
# Validation loss: 0.2955713985448188
# Validation Accuracy : 0.9007290005683899
#
#
# ____________________Running Epoch 22____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.16588660012534323
# This epoch took 7 seconds to train
#
# Validation loss: 0.31150060099490146
# Validation Accuracy : 0.8974401354789734
#
#
# ____________________Running Epoch 23____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.16128519133843006
# This epoch took 7 seconds to train
#
# Validation loss: 0.2937551001284985
# Validation Accuracy : 0.901619553565979
#
#
# ____________________Running Epoch 24____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.15751371707053893
# This epoch took 7 seconds to train
#
# Validation loss: 0.3014197054695576
# Validation Accuracy : 0.9018213152885437
#
#
# ____________________Running Epoch 25____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.15028477456182876
# This epoch took 7 seconds to train
#
# Validation loss: 0.31718595928334176
# Validation Accuracy : 0.89453125
#
#
# ____________________Running Epoch 26____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.14649233439976864
# This epoch took 7 seconds to train
#
# Validation loss: 0.31211604843748375
# Validation Accuracy : 0.8992804884910583
#
#
# ____________________Running Epoch 27____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.14104842069618245
# This epoch took 7 seconds to train
#
# Validation loss: 0.3276212250298642
# Validation Accuracy : 0.8973214030265808
#
#
# ____________________Running Epoch 28____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.13870381991913977
# This epoch took 7 seconds to train
#
# Validation loss: 0.3290675361739828
# Validation Accuracy : 0.8992329835891724
#
#
# ____________________Running Epoch 29____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.13489420252277495
# This epoch took 6 seconds to train
#
# Validation loss: 0.32688575792819896
# Validation Accuracy : 0.898021936416626
#
#
# ____________________Running Epoch 30____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.12962926696351867
# This epoch took 7 seconds to train
#
# Validation loss: 0.33373406497721975
# Validation Accuracy : 0.8994823098182678
#
#
# ____________________Running Epoch 31____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.127462954319855
# This epoch took 7 seconds to train
#
# Validation loss: 0.3497891070994925
# Validation Accuracy : 0.8995179533958435
#
#
# ____________________Running Epoch 32____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.12099564883937226
# This epoch took 7 seconds to train
#
# Validation loss: 0.3418787312000356
# Validation Accuracy : 0.893700122833252
#
#
# ____________________Running Epoch 33____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11862151780502593
# This epoch took 7 seconds to train
#
# Validation loss: 0.33930972789196256
# Validation Accuracy : 0.8973689079284668
#
#
# ____________________Running Epoch 34____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11034964904823202
# This epoch took 6 seconds to train
#
# Validation loss: 0.35071910822645147
# Validation Accuracy : 0.8984018564224243
#
#
# ____________________Running Epoch 35____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.10785677717958993
# This epoch took 6 seconds to train
#
# Validation loss: 0.3436410328809251
# Validation Accuracy : 0.8969414830207825
#
#
# ____________________Running Epoch 36____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.10835095970554555
# This epoch took 6 seconds to train
#
# Validation loss: 0.35829187200424517
# Validation Accuracy : 0.9016313552856445
#
#
# ____________________Running Epoch 37____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.10374607682782919
# This epoch took 7 seconds to train
#
# Validation loss: 0.3772701345225598
# Validation Accuracy : 0.8969414830207825
#
#
# ____________________Running Epoch 38____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.09784119881372502
# This epoch took 7 seconds to train
#
# Validation loss: 0.3857480509484068
# Validation Accuracy : 0.9008952379226685
#
#
# ____________________Running Epoch 39____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.10512724782320414
# This epoch took 6 seconds to train
#
# Validation loss: 0.3767650786866533
# Validation Accuracy : 0.897416353225708
#
#
# ____________________Running Epoch 40____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.09456369970390137
# This epoch took 6 seconds to train
#
# Validation loss: 0.3868496941125139
# Validation Accuracy : 0.8985443711280823
#
#
# ____________________Running Epoch 41____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.09130454546910652
# This epoch took 6 seconds to train
#
# Validation loss: 0.3892735258695927
# Validation Accuracy : 0.8965259194374084
#
#
# ____________________Running Epoch 42____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.08708850970055829
# This epoch took 7 seconds to train
#
# Validation loss: 0.4093202105227937
# Validation Accuracy : 0.8945074677467346
#
#
# ____________________Running Epoch 43____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.08420440865720207
# This epoch took 6 seconds to train
#
# Validation loss: 0.4114074171223539
# Validation Accuracy : 0.8979388475418091
#
#
# ____________________Running Epoch 44____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.0835481265738131
# This epoch took 6 seconds to train
#
# Validation loss: 0.41515952919391874
# Validation Accuracy : 0.8982238173484802
#
#
# ____________________Running Epoch 45____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.07457331693830326
# This epoch took 7 seconds to train
#
# Validation loss: 0.41342515450842837
# Validation Accuracy : 0.8960629105567932
#
#
# ____________________Running Epoch 46____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.07620469451029883
# This epoch took 7 seconds to train
#
# Validation loss: 0.4640865053268189
# Validation Accuracy : 0.8914086222648621
#
#
# ____________________Running Epoch 47____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.07030449292444169
# This epoch took 7 seconds to train
#
# Validation loss: 0.45792631963466074
# Validation Accuracy : 0.8957779407501221
#
#
# ____________________Running Epoch 48____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.07192350627775206
# This epoch took 7 seconds to train
#
# Validation loss: 0.48534032321990805
# Validation Accuracy : 0.8935813903808594
#
#
# ____________________Running Epoch 49____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.06701106446339412
# This epoch took 7 seconds to train
#
# Validation loss: 0.46532782531799155
# Validation Accuracy : 0.8937119841575623
#
#
# ____________________Running Epoch 50____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.06377261252875657
# This epoch took 7 seconds to train
#
# Validation loss: 0.4721663556200393
# Validation Accuracy : 0.8965734243392944
#
#
# Accuracy on the test set is: 0.8900390863418579

# %%
model_overfitting=Lenet5_ext(28, 10, lr=0.001, epochs=50,use_cuda=True,use_drop_out=False,use_batch_norm=False)
model_overfitting.train_loop(trainloader, valiloader)
model_overfitting.testing(testloader)
# Out:
# Not using Dropout
# Not using Batch Normalization
# Using GPU
# ____________________Running Epoch 1____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.8522664343423032
# This epoch took 6 seconds to train
#
# Validation loss: 0.5862548782470378
# Validation Accuracy : 0.7754083871841431
#
#
# ____________________Running Epoch 2____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.5235228717644164
# This epoch took 6 seconds to train
#
# Validation loss: 0.49906437637958123
# Validation Accuracy : 0.8118588924407959
#
#
# ____________________Running Epoch 3____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.45574572539709984
# This epoch took 6 seconds to train
#
# Validation loss: 0.45319073124134795
# Validation Accuracy : 0.8351776599884033
#
#
# ____________________Running Epoch 4____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.4136160471020861
# This epoch took 6 seconds to train
#
# Validation loss: 0.40285891801752943
# Validation Accuracy : 0.8539015054702759
#
#
# ____________________Running Epoch 5____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.3811818575288387
# This epoch took 6 seconds to train
#
# Validation loss: 0.3780522422587618
# Validation Accuracy : 0.8628894686698914
#
#
# ____________________Running Epoch 6____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.35937976417072276
# This epoch took 6 seconds to train
#
# Validation loss: 0.38196508808338897
# Validation Accuracy : 0.8584845662117004
#
#
# ____________________Running Epoch 7____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.3389805602900525
# This epoch took 6 seconds to train
#
# Validation loss: 0.35932542098329423
# Validation Accuracy : 0.8710581064224243
#
#
# ____________________Running Epoch 8____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.3238392442147783
# This epoch took 6 seconds to train
#
# Validation loss: 0.3455695814274727
# Validation Accuracy : 0.8730646371841431
#
#
# ____________________Running Epoch 9____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.313618752629833
# This epoch took 6 seconds to train
#
# Validation loss: 0.33007237885860685
# Validation Accuracy : 0.8799154162406921
#
#
# ____________________Running Epoch 10____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.30301326164539827
# This epoch took 6 seconds to train
#
# Validation loss: 0.3265706050269147
# Validation Accuracy : 0.8790131211280823
#
#
# ____________________Running Epoch 11____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2903001792728901
# This epoch took 6 seconds to train
#
# Validation loss: 0.33480913081067676
# Validation Accuracy : 0.8792505264282227
#
#
# ____________________Running Epoch 12____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.28328951923771106
# This epoch took 6 seconds to train
#
# Validation loss: 0.31358962458498935
# Validation Accuracy : 0.8863388299942017
#
#
# ____________________Running Epoch 13____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2760707392813043
# This epoch took 6 seconds to train
#
# Validation loss: 0.319690300429121
# Validation Accuracy : 0.8868256211280823
#
#
# ____________________Running Epoch 14____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2679115713752331
# This epoch took 6 seconds to train
#
# Validation loss: 0.30157762639066005
# Validation Accuracy : 0.8930470943450928
#
#
# ____________________Running Epoch 15____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.25722513149710413
# This epoch took 6 seconds to train
#
# Validation loss: 0.2986876133908617
# Validation Accuracy : 0.8907199501991272
#
#
# ____________________Running Epoch 16____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.25349947088893426
# This epoch took 6 seconds to train
#
# Validation loss: 0.2933451238464802
# Validation Accuracy : 0.8924296498298645
#
#
# ____________________Running Epoch 17____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.24827234185439476
# This epoch took 6 seconds to train
#
# Validation loss: 0.29235856013095124
# Validation Accuracy : 0.8924296498298645
#
#
# ____________________Running Epoch 18____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.24000476261085651
# This epoch took 6 seconds to train
#
# Validation loss: 0.29414650766139333
# Validation Accuracy : 0.8943293690681458
#
#
# ____________________Running Epoch 19____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.23536239524788044
# This epoch took 6 seconds to train
#
# Validation loss: 0.29403185590784603
# Validation Accuracy : 0.8955998420715332
#
#
# ____________________Running Epoch 20____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.23112888943324697
# This epoch took 6 seconds to train
#
# Validation loss: 0.287356232392027
# Validation Accuracy : 0.894946813583374
#
#
# ____________________Running Epoch 21____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.22231624552861173
# This epoch took 6 seconds to train
#
# Validation loss: 0.28487092129727626
# Validation Accuracy : 0.8966565132141113
#
#
# ____________________Running Epoch 22____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.22020886014116572
# This epoch took 6 seconds to train
#
# Validation loss: 0.27998052378918264
# Validation Accuracy : 0.8963834643363953
#
#
# ____________________Running Epoch 23____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.21616999376961527
# This epoch took 6 seconds to train
#
# Validation loss: 0.2991001355521222
# Validation Accuracy : 0.8910287022590637
#
#
# ____________________Running Epoch 24____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.2126867523852815
# This epoch took 6 seconds to train
#
# Validation loss: 0.28436668502523543
# Validation Accuracy : 0.8960391283035278
#
#
# ____________________Running Epoch 25____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.20637066860465295
# This epoch took 6 seconds to train
#
# Validation loss: 0.27698272656887135
# Validation Accuracy : 0.8984137177467346
#
#
# ____________________Running Epoch 26____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1985974171535766
# This epoch took 6 seconds to train
#
# Validation loss: 0.2907331189576616
# Validation Accuracy : 0.8971551656723022
#
#
# ____________________Running Epoch 27____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.19945586036811483
# This epoch took 6 seconds to train
#
# Validation loss: 0.2777639462592754
# Validation Accuracy : 0.9024506211280823
#
#
# ____________________Running Epoch 28____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.19434646929198124
# This epoch took 6 seconds to train
#
# Validation loss: 0.28194887302023297
# Validation Accuracy : 0.8991498947143555
#
#
# ____________________Running Epoch 29____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.18936627100598305
# This epoch took 6 seconds to train
#
# Validation loss: 0.29667069620274483
# Validation Accuracy : 0.8962647318840027
#
#
# ____________________Running Epoch 30____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.18307709697871766
# This epoch took 6 seconds to train
#
# Validation loss: 0.284847506500305
# Validation Accuracy : 0.8961341381072998
#
#
# ____________________Running Epoch 31____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.17847476059452017
# This epoch took 6 seconds to train
#
# Validation loss: 0.3060991605545612
# Validation Accuracy : 0.8925127983093262
#
#
# ____________________Running Epoch 32____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.17745520975044432
# This epoch took 7 seconds to train
#
# Validation loss: 0.29011538719877283
# Validation Accuracy : 0.9007290005683899
#
#
# ____________________Running Epoch 33____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.17231485592399506
# This epoch took 7 seconds to train
#
# Validation loss: 0.2899749542170383
# Validation Accuracy : 0.8995179533958435
#
#
# ____________________Running Epoch 34____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.16759523935616016
# This epoch took 6 seconds to train
#
# Validation loss: 0.30009108433063997
# Validation Accuracy : 0.9002066254615784
#
#
# ____________________Running Epoch 35____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1615656208484731
# This epoch took 6 seconds to train
#
# Validation loss: 0.29892684138835746
# Validation Accuracy : 0.8993517160415649
#
#
# ____________________Running Epoch 36____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.16049967674498863
# This epoch took 6 seconds to train
#
# Validation loss: 0.2962446599564654
# Validation Accuracy : 0.8996723294258118
#
#
# ____________________Running Epoch 37____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1524910576086729
# This epoch took 6 seconds to train
#
# Validation loss: 0.30896585704164303
# Validation Accuracy : 0.9006696939468384
#
#
# ____________________Running Epoch 38____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.15223087350580286
# This epoch took 6 seconds to train
#
# Validation loss: 0.300047737486819
# Validation Accuracy : 0.8987581133842468
#
#
# ____________________Running Epoch 39____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1481729895669095
# This epoch took 6 seconds to train
#
# Validation loss: 0.30006833406204875
# Validation Accuracy : 0.9016669988632202
#
#
# ____________________Running Epoch 40____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.14589746688750196
# This epoch took 6 seconds to train
#
# Validation loss: 0.32640157164411343
# Validation Accuracy : 0.8970127701759338
#
#
# ____________________Running Epoch 41____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.142027644242378
# This epoch took 6 seconds to train
#
# Validation loss: 0.30897704844779156
# Validation Accuracy : 0.9004083871841431
#
#
# ____________________Running Epoch 42____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.13911159312788476
# This epoch took 6 seconds to train
#
# Validation loss: 0.3296998545844504
# Validation Accuracy : 0.9001947045326233
#
#
# ____________________Running Epoch 43____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.13505924199806882
# This epoch took 6 seconds to train
#
# Validation loss: 0.32682886370953096
# Validation Accuracy : 0.8980812430381775
#
#
# ____________________Running Epoch 44____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.12983661878140682
# This epoch took 6 seconds to train
#
# Validation loss: 0.3345915304219469
# Validation Accuracy : 0.8968346118927002
#
#
# ____________________Running Epoch 45____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.1284446752768882
# This epoch took 6 seconds to train
#
# Validation loss: 0.3289049527746566
# Validation Accuracy : 0.9037448167800903
#
#
# ____________________Running Epoch 46____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.12968924883356753
# This epoch took 6 seconds to train
#
# Validation loss: 0.33273058400509203
# Validation Accuracy : 0.9023199677467346
#
#
# ____________________Running Epoch 47____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.12031283047288022
# This epoch took 6 seconds to train
#
# Validation loss: 0.3653250279578757
# Validation Accuracy : 0.8943887948989868
#
#
# ____________________Running Epoch 48____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11756751609054651
# This epoch took 6 seconds to train
#
# Validation loss: 0.36196582082738266
# Validation Accuracy : 0.8968583941459656
#
#
# ____________________Running Epoch 49____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11391345005323912
# This epoch took 6 seconds to train
#
# Validation loss: 0.3571312877726048
# Validation Accuracy : 0.8974639177322388
#
#
# ____________________Running Epoch 50____________________________________________________________________________________________________________________________________________________________________________________
#
# Training loss: 0.11472398702530785
# This epoch took 6 seconds to train
#
# Validation loss: 0.3583981727666043
# Validation Accuracy : 0.8987224698066711
#
#
# Accuracy on the test set is: 0.8921874761581421

# %% [markdown]
# We see that the the performance on the training set with batch normalization and without it is pretty much the same although the model without normalization actually performs better by 0.2%.
